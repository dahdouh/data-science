# %%
import matplotlib.pyplot as plt
import pandas as pd

url = "claimskg_result.csv"
df=pd.read_csv(url)

df
# Out:
#                                                      id  \
# 0     http://data.gesis.org/claimskg/claim_review/be...
# 1     http://data.gesis.org/claimskg/claim_review/8a...
# 2     http://data.gesis.org/claimskg/claim_review/c2...
# 3     http://data.gesis.org/claimskg/claim_review/1e...
# 4     http://data.gesis.org/claimskg/claim_review/0b...
# ...                                                 ...
# 9995  http://data.gesis.org/claimskg/claim_review/e8...
# 9996  http://data.gesis.org/claimskg/claim_review/d2...
# 9997  http://data.gesis.org/claimskg/claim_review/0e...
# 9998  http://data.gesis.org/claimskg/claim_review/c9...
# 9999  http://data.gesis.org/claimskg/claim_review/d1...
#
#                                                    text        date  \
# 0     Malia Obama cashed a $1.2 million tax refund c...     Unknown
# 1     High diver is saved from jumping into a draine...     Unknown
# 2     'And the revenue generated by drilling off Vir...  2012-02-15
# 3     Health insurance companies pay CEOs $24 millio...  2009-09-15
# 4     Ted Cruz said that veterans should start selli...     Unknown
# ...                                                 ...         ...
# 9995  While in the Illinois Senate, Barack Obama pas...  2008-08-25
# 9996  'The tuitions in Virginia colleges...have doub...  2010-11-30
# 9997  'Trump Management was charged with discriminat...  2016-08-26
# 9998  The NAACP is calling for the removal of an his...     Unknown
# 9999  'Ted Cruz tried to ban contraception' five times.  2015-12-01
#
#      ratingName                       author  \
# 0         OTHER                      Unknown
# 1         OTHER                      Unknown
# 2       MIXTURE                    Jim Moran
# 3       MIXTURE  Health Care for America Now
# 4         FALSE                      Unknown
# ...         ...                          ...
# 9995    MIXTURE               Michelle Obama
# 9996       TRUE                Bob McDonnell
# 9997       TRUE              Hillary Clinton
# 9998    MIXTURE                      Unknown
# 9999    MIXTURE              Hillary Clinton
#
#                                                headline  \
# 0            Did Malia Obama Cash a $1.2 Million Check?
# 1                             High Diver Saved By Cross
# 2     Moran says drilling off Virginia's coast will ...
# 3     Health care advocacy group blasts insurers for...
# 4     Ted Cruz: Vets Should Sell Cookies for Funding...
# ...                                                 ...
# 9995           Obama sponsored earned income tax credit
# 9996  Bob McDonnell says Virginia college tuitions h...
# 9997  Clinton ad: Trump Management was charged with ...
# 9998  Does the NAACP Want to Sandblast Confederate F...
# 9999  Hillary Clinton's exaggerated claim that Ted C...
#
#                                    named_entities_claim  \
# 0     Facebook,Fan Fiction,Junk News,Malia Obama,Sno...
# 1     Cincinnati Post,Islam,Scripture lesson,Univers...
# 2     Alaska,American Petroleum Institute,Atlantic O...
# 3     Aetna,Assurant,Bloomberg News,Cigna,Coventry H...
# 4     David Nelson,James Morrison,John Scalzi,Republ...
# ...                                                 ...
# 9995  Barack Obama,Illinois Senate,Internal Revenue ...
# 9996  2009 Stimulus Act,Bob McDonnell,James Madison ...
# 9997  Art of the Deal,Civil Rights Act of 1968,Donal...
# 9998  Atlanta Journal-Constitution,Charleston massac...
# 9999  Affordable Care Act,Association of Reproductiv...
#
#                                  named_entities_article  \
# 0                                           Malia Obama
# 1                                    shadow on the wall
# 2                                                   NaN
# 3                                                   NaN
# 4                                              Ted Cruz
# ...                                                 ...
# 9995  Barack Obama,Illinois Senate,hard-working fami...
# 9996                                                NaN
# 9997                                                NaN
# 9998                      NAACP,Stone Mountain, Georgia
# 9999                                           Ted Cruz
#
#                                                keywords          source  \
# 0                                                   NaN  truthorfiction
# 1                                           ASP Article          snopes
# 2                                 Energy,State Finances      politifact
# 3                              Corporations,Health Care      politifact
# 4                 ASP Article, Not Necessarily The News          snopes
# ...                                                 ...             ...
# 9995                                              Taxes      politifact
# 9996                                          Education      politifact
# 9997  Candidate Biography,Civil Rights,Housing,Legal...      politifact
# 9998                              NAACP, stone mountain          snopes
# 9999                               Abortion,Health Care      politifact
#
#                            sourceURL  \
# 0     https://www.truthorfiction.com
# 1              http://www.snopes.com
# 2          http://www.politifact.com
# 3          http://www.politifact.com
# 4              http://www.snopes.com
# ...                              ...
# 9995       http://www.politifact.com
# 9996       http://www.politifact.com
# 9997       http://www.politifact.com
# 9998           http://www.snopes.com
# 9999       http://www.politifact.com
#
#                                                    link language  truthRating
# 0     https://www.truthorfiction.com/did-malia-obama...  English           -1
# 1     https://www.snopes.com/fact-check/high-and-mig...  English           -1
# 2     http://www.politifact.com/virginia/statements/...  English            2
# 3     http://www.politifact.com/truth-o-meter/statem...  English            2
# 4       https://www.snopes.com/fact-check/cruz-cookies/  English            1
# ...                                                 ...      ...          ...
# 9995  http://www.politifact.com/truth-o-meter/statem...  English            2
# 9996  http://www.politifact.com/virginia/statements/...  English            3
# 9997  http://www.politifact.com/truth-o-meter/statem...  English            3
# 9998  https://www.snopes.com/fact-check/naacp-wants-...  English            2
# 9999  http://www.politifact.com/truth-o-meter/statem...  English            2
#
# [10000 rows x 14 columns]

# %%
df.plot(kind='hist', subplots=True,
 layout=(2,2), figsize=(6,6),
 sharex=False, title='Histogramme')
plt.show()

# %%
df['ratingName'].value_counts().plot(kind='pie',
figsize=(6,6),
title='Pie',
fontsize=11,
legend=True,
autopct='%1.1f%%')

plt.show()

# %%
df = pd.DataFrame()

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrameNone

# %%
g=df.loc[(df["author"]=="Donald Trump") & (df["ratingName"]=="MIXTURE")]


print(df["author"].value_counts())
print ("Nombre de Donald Trump : ",
 g['id'].count())

print("Taux de Unknown : ",
 g['id'].count()/df['id'].count())

print("Nombre total de Author",df['id'].count())

t=df.loc[(df["keywords"]=="NaN")]

a=df.loc[(df["author"]=="Bill Nelson")]

print("Nombre total de bill Nelson:",a['id'].count())

print("Nombre de NaN :",t['id'].count())
# Out:
# Unknown                                4829
# Donald Trump                            200
# Barack Obama                            172
# Bloggers                                138
# Facebook posts                           86
# Hillary Clinton                          83
# Multiple sources                         80
# Viral image                              67
# Rick Scott                               60
# multiple sources                         58
# Rick Perry                               57
# John McCain                              55
# Scott Walker                             54
# Mitt Romney                              53
# Chain email                              45
# Bernie Sanders                           44
# Marco Rubio                              41
# Ted Cruz                                 38
# Charlie Crist                            30
# Newt Gingrich                            28
# Paul Ryan                                28
# Chris Christie                           27
# Joe Biden                                26
# John Kasich                              21
# Tim Kaine                                20
# Rob Portman                              19
# Mike Pence                               19
# John Boehner                             19
# Rush Limbaugh                            19
# Greg Abbott                              18
#                                        ...
# Health Care for America Now               1
# James Bennett                             1
# Ken Detzner                               1
# Tracy McCreery                            1
# Michael J. Gardiner                       1
# Freedom Partners Action Fund              1
# Georgia Lottery                           1
# Philip Hammond                            1
# Anthony Scaramucci                        1
# Pink Slip Rick                            1
# Howard Schultz                            1
# Daily World Update                        1
# Shirley Turner                            1
# Rex Tillerson                             1
# Kareem Abdul-Jabbar                       1
# John Calipari                             1
# Jason Smith                               1
# Donald McEachin                           1
# Oregon Citizens Lobby                     1
# Chelsea Clinton                           1
# Adan Ballesteros                          1
# Maurice Ferre                             1
# Tom Kean                                  1
# Snapchat                                  1
# Burnt Orange Report                       1
# Mike Dovilla                              1
# Stop 57 campaign                          1
# Committee for Our Children's Future       1
# Nicole Galloway                           1
# Burger King                               1
# Name: author, Length: 1997, dtype: int64
# Nombre de Donald Trump :  95
# Taux de Unknown :  0.0095
# Nombre total de Author 10000
# Nombre total de bill Nelson: 8
# Nombre de NaN : 0

# %%
display(df.head())

# %%
df = df.drop(['id','date','sourceURL','link','language'], axis = 1)
display(df.head())
# Out:
#                                                 text ratingName  \
# 0  Malia Obama cashed a $1.2 million tax refund c...      OTHER
# 1  High diver is saved from jumping into a draine...      OTHER
# 2  'And the revenue generated by drilling off Vir...    MIXTURE
# 3  Health insurance companies pay CEOs $24 millio...    MIXTURE
# 4  Ted Cruz said that veterans should start selli...      FALSE
#
#                         author  \
# 0                      Unknown
# 1                      Unknown
# 2                    Jim Moran
# 3  Health Care for America Now
# 4                      Unknown
#
#                                             headline  \
# 0         Did Malia Obama Cash a $1.2 Million Check?
# 1                          High Diver Saved By Cross
# 2  Moran says drilling off Virginia's coast will ...
# 3  Health care advocacy group blasts insurers for...
# 4  Ted Cruz: Vets Should Sell Cookies for Funding...
#
#                                 named_entities_claim named_entities_article  \
# 0  Facebook,Fan Fiction,Junk News,Malia Obama,Sno...            Malia Obama
# 1  Cincinnati Post,Islam,Scripture lesson,Univers...     shadow on the wall
# 2  Alaska,American Petroleum Institute,Atlantic O...                    NaN
# 3  Aetna,Assurant,Bloomberg News,Cigna,Coventry H...                    NaN
# 4  David Nelson,James Morrison,John Scalzi,Republ...               Ted Cruz
#
#                                 keywords          source  truthRating
# 0                                    NaN  truthorfiction           -1
# 1                            ASP Article          snopes           -1
# 2                  Energy,State Finances      politifact            2
# 3               Corporations,Health Care      politifact            2
# 4  ASP Article, Not Necessarily The News          snopes            1

# %%
df = df.drop(['named_entities_claim','named_entities_article'],1)

# %%
display(df.head())
# Out:
#                                                 text ratingName  \
# 0  Malia Obama cashed a $1.2 million tax refund c...      OTHER
# 1  High diver is saved from jumping into a draine...      OTHER
# 2  'And the revenue generated by drilling off Vir...    MIXTURE
# 3  Health insurance companies pay CEOs $24 millio...    MIXTURE
# 4  Ted Cruz said that veterans should start selli...      FALSE
#
#                         author  \
# 0                      Unknown
# 1                      Unknown
# 2                    Jim Moran
# 3  Health Care for America Now
# 4                      Unknown
#
#                                             headline  \
# 0         Did Malia Obama Cash a $1.2 Million Check?
# 1                          High Diver Saved By Cross
# 2  Moran says drilling off Virginia's coast will ...
# 3  Health care advocacy group blasts insurers for...
# 4  Ted Cruz: Vets Should Sell Cookies for Funding...
#
#                                 keywords          source  truthRating
# 0                                    NaN  truthorfiction           -1
# 1                            ASP Article          snopes           -1
# 2                  Energy,State Finances      politifact            2
# 3               Corporations,Health Care      politifact            2
# 4  ASP Article, Not Necessarily The News          snopes            1

# %%
df = df.drop('ratingName',1)

# %%
display(df.head())
# Out:
#                                                 text  \
# 0  Malia Obama cashed a $1.2 million tax refund c...
# 1  High diver is saved from jumping into a draine...
# 2  'And the revenue generated by drilling off Vir...
# 3  Health insurance companies pay CEOs $24 millio...
# 4  Ted Cruz said that veterans should start selli...
#
#                         author  \
# 0                      Unknown
# 1                      Unknown
# 2                    Jim Moran
# 3  Health Care for America Now
# 4                      Unknown
#
#                                             headline  \
# 0         Did Malia Obama Cash a $1.2 Million Check?
# 1                          High Diver Saved By Cross
# 2  Moran says drilling off Virginia's coast will ...
# 3  Health care advocacy group blasts insurers for...
# 4  Ted Cruz: Vets Should Sell Cookies for Funding...
#
#                                 keywords          source  truthRating
# 0                                    NaN  truthorfiction           -1
# 1                            ASP Article          snopes           -1
# 2                  Energy,State Finances      politifact            2
# 3               Corporations,Health Care      politifact            2
# 4  ASP Article, Not Necessarily The News          snopes            1

# %%
text = df.loc[5]
vtext = text['text']
print(vtext)
# Out:
# Passengers on an airliner diverted to Cuba thought the hijacking was a Candid Camera stunt due to the coincidental presence of the show's host, Allen Funt.

# %%
import nltk
import contractions
import unicodedata
import re
import inflect
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))

def replace_contractions(text):
     return contractions.fix(text)

vtexts=replace_contractions(vtext)


textEnMot = word_tokenize(vtexts)
textEnMot = [m.lower() for m in textEnMot]

print(textEnMot)
# Out:
# ['passengers', 'on', 'an', 'airliner', 'diverted', 'to', 'cuba', 'thought', 'the', 'hijacking', 'was', 'a', 'candid', 'camera', 'stunt', 'due', 'to', 'the', 'coincidental', 'presence', 'of', 'the', 'show', "'s", 'host', ',', 'allen', 'funt', '.']

# %%
textEnMot = [mot for mot in textEnMot if mot.isalpha()]

print(textEnMot)

print('****************')

print(stop_words)
# Out:
# ['passengers', 'on', 'an', 'airliner', 'diverted', 'to', 'cuba', 'thought', 'the', 'hijacking', 'was', 'a', 'candid', 'camera', 'stunt', 'due', 'to', 'the', 'coincidental', 'presence', 'of', 'the', 'show', 'host', 'allen', 'funt']
# ****************
# {'so', 'y', 'doing', 'from', 'having', 'i', 'out', 'myself', 'just', 't', 'yourself', 'ma', 'with', "you're", 've', 'most', "didn't", 'him', "don't", 'haven', "mightn't", 'his', "should've", 'until', 'yours', 'into', "wouldn't", 'what', 'these', 'while', 'can', 'should', 'were', "doesn't", 'we', 'about', 'only', 'between', 'ain', 'than', 'weren', 'all', 'same', "needn't", 'hadn', 'that', 'it', 'has', 'shouldn', 'up', "hasn't", 'be', "that'll", 'too', 'during', 'm', 'ourselves', 'she', 'this', 'are', 'after', 'other', 'mustn', 'nor', 'because', 'is', 'does', 'here', 'then', 'both', "isn't", 'not', 'will', 'but', 'before', 'o', 'aren', "shan't", 'have', 'such', 'being', 'some', 'didn', 'further', 'am', 'now', 'off', 'its', 'you', 'any', 'our', 'he', "hadn't", "it's", 'your', "shouldn't", "weren't", 'ours', 'own', "couldn't", 're', 'which', 'below', "wasn't", 'of', "aren't", 'wouldn', 'and', 'the', 'been', 'for', 'through', 'theirs', 'their', 'yourselves', 'do', 'above', 'doesn', 'who', 's', 'hasn', 'those', 'll', 'to', 'was', 'hers', 'or', 'won', 'when', 'each', 'me', 'a', 'in', "you'll", 'couldn', 'mightn', 'by', 'whom', 'where', "she's", 'very', 'himself', 'once', 'as', "you've", 'if', 'my', 'them', 'few', 'they', 'her', "mustn't", 'isn', 'down', 'there', 'an', 'on', 'don', 'again', 'no', 'under', 'itself', 'themselves', 'did', 'at', 'more', "haven't", 'had', 'over', 'herself', 'wasn', 'd', 'needn', 'how', 'shan', 'why', "won't", "you'd", 'against'}

# %%
#suppression des stop words

stop_words = set(stopwords.words('english'))
textEnMot = [stw for stw in textEnMot if not stw in stop_words]

print(textEnMot)
# Out:
# ['passengers', 'airliner', 'diverted', 'cuba', 'thought', 'hijacking', 'candid', 'camera', 'stunt', 'due', 'coincidental', 'presence', 'show', 'host', 'allen', 'funt']

# %%
lematiseur = WordNetLemmatizer()

lem = [lematiseur.lemmatize(word,pos='v') for word in textEnMot]

print(lem)
# Out:
# ['passengers', 'on', 'an', 'airliner', 'divert', 'to', 'cuba', 'think', 'the', 'hijack', 'be', 'a', 'candid', 'camera', 'stunt', 'due', 'to', 'the', 'coincidental', 'presence', 'of', 'the', 'show', "'s", 'host', ',', 'allen', 'funt', '.']

# %%
def remove_non_ascii(words):
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word) 
    return new_words

def remove_punctuation(words):
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

def remove_stopwords(words):
    new_words = []
    for word in words:
        if word not in stopwords.words('english'):
            new_words.append(word)
    return new_words

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = replace_numbers(words)
    words = remove_punctuation(words)
    words = remove_stopwords(words)
    return words

def clean_text(text):
    tokens = word_tokenize(text)
    tokens=normalize(tokens)
    text="".join([" "+i for i in tokens]).strip()
    return text

# %%
def clean_news (data):
    for i in range(len(data)):
        #print (i)
        data[i]=clean_text(data[i])
    return data    
display(df.head())
# Out:
#                                                 text  \
# 0  Malia Obama cashed a $1.2 million tax refund c...
# 1  High diver is saved from jumping into a draine...
# 2  'And the revenue generated by drilling off Vir...
# 3  Health insurance companies pay CEOs $24 millio...
# 4  Ted Cruz said that veterans should start selli...
#
#                         author  \
# 0                      Unknown
# 1                      Unknown
# 2                    Jim Moran
# 3  Health Care for America Now
# 4                      Unknown
#
#                                             headline  \
# 0         Did Malia Obama Cash a $1.2 Million Check?
# 1                          High Diver Saved By Cross
# 2  Moran says drilling off Virginia's coast will ...
# 3  Health care advocacy group blasts insurers for...
# 4  Ted Cruz: Vets Should Sell Cookies for Funding...
#
#                                 keywords          source  truthRating
# 0                                    NaN  truthorfiction           -1
# 1                            ASP Article          snopes           -1
# 2                  Energy,State Finances      politifact            2
# 3               Corporations,Health Care      politifact            2
# 4  ASP Article, Not Necessarily The News          snopes            1

# %%
#Nettoyage du texte :

df['text']=clean_news(df['text'])  

display(df.head())
#vectorisation des donnees textuelles

vectorizer = TfidfVectorizer()
vecteurs = vectorizer.fit_transform(df.text)


#variables à prédire et de la classe X et y

X = vecteurs.toarray()

y = df.truthRating
# Out:
# /home/tazby/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
from sklearn.model_selection import train_test_split

taille_validation=0.3 

tailletests= 1-taille_validation

seed=30
X_train,X_test,y_train,y_test=train_test_split(X, 
                                               y, 
                                               train_size=taille_validation, 
                                               random_state=seed,
                                               test_size=tailletests)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from time import time

seed=7
k_fold = KFold(n_splits=10, shuffle=True, random_state=seed)
clf = GaussianNB()

scoring = 'accuracy'
t0 = time()
score = cross_val_score(clf, X, y, cv=k_fold, scoring=scoring)
print("Réalisé en %0.3fs" % (time() - t0))

print('Les différentes accuracy pour les 10 évaluations sont : \n',
      score,'\n')
print ('Accuracy moyenne : ',score.mean(), 
       ' standard deviation', score.std())
