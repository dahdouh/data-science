# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import pandas as pd
import numpy as np
#https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
url="/home/karim/Documents/Aigle/S2/Sciences de donnees/projet/claimskg_result.csv"


df = pd.read_csv(url, usecols=["source", "author", "truthRating", "ratingName"])
# 5 premières lignes du fichier
display(df.head())
# Out:
#   ratingName                       author          source  truthRating
# 0      OTHER                      Unknown  truthorfiction           -1
# 1      OTHER                      Unknown          snopes           -1
# 2    MIXTURE                    Jim Moran      politifact            2
# 3    MIXTURE  Health Care for America Now      politifact            2
# 4      FALSE                      Unknown          snopes            1

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)
D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]

array = df.values 
#entree du modèle Naives Ba
X = array[:,0:3] 
#y sortie du modèle NB
y = array[:,3]

D = v.fit_transform(y)
print(D)

display(X)
display(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-5771b8f14a8f> in <module>
#      10 y = array[:,3]
#      11
# ---> 12 D = v.fit_transform(y)
#      13 print(D)
#      14
#
# ~/env/lib/python3.6/site-packages/sklearn/feature_extraction/_dict_vectorizer.py in fit_transform(self, X, y)
#     226             Feature vectors; always 2-d.
#     227         """
# --> 228         return self._transform(X, fitting=True)
#     229
#     230     def inverse_transform(self, X, dict_type=dict):
#
# ~/env/lib/python3.6/site-packages/sklearn/feature_extraction/_dict_vectorizer.py in _transform(self, X, fitting)
#     163         # same time
#     164         for x in X:
# --> 165             for f, v in x.items():
#     166                 if isinstance(v, str):
#     167                     f = "%s%s%s" % (f, self.separator, v)
#
# ...

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()

clf.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f7acc3d0f5a9> in <module>
#       4 clf = GaussianNB()
#       5
# ----> 6 clf.fit(X, y)
#
# ~/env/lib/python3.6/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# ~/env/lib/python3.6/site-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     357         self : object
#     358         """
# --> 359         X, y = check_X_y(X, y)
#     360         if sample_weight is not None:
#     361             sample_weight = _check_sample_weight(sample_weight, X)
#
# ...
